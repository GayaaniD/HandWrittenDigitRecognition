# %% [markdown]
# import libraries

# %%
import numpy as np
from sklearn.datasets import load_digits

# %% [markdown]
# load dataset

# %%
dataset = load_digits()

# %% [markdown]
# summarize data

# %%
print(dataset.data)
print(dataset.target)

print(dataset.data.shape)
print(dataset.images.shape)

dataimageLength = len(dataset.images)
print(dataimageLength)
# Out:
# [[ 0.  0.  5. ...  0.  0.  0.]
#  [ 0.  0.  0. ... 10.  0.  0.]
#  [ 0.  0.  0. ... 16.  9.  0.]
#  ...
#  [ 0.  0.  1. ...  6.  0.  0.]
#  [ 0.  0.  2. ... 12.  0.  0.]
#  [ 0.  0. 10. ... 12.  1.  0.]]
# [0 1 2 ... 8 9 8]
# (1797, 64)
# (1797, 8, 8)
# 1797

# %% [markdown]
# visualize the data

# %%
n=5
import matplotlib.pyplot as plt
plt.gray()
plt.matshow(dataset.images[n])
plt.show()

dataset.images[n]
# Out:
# array([[ 0.,  0., 12., 10.,  0.,  0.,  0.,  0.],
#        [ 0.,  0., 14., 16., 16., 14.,  0.,  0.],
#        [ 0.,  0., 13., 16., 15., 10.,  1.,  0.],
#        [ 0.,  0., 11., 16., 16.,  7.,  0.,  0.],
#        [ 0.,  0.,  0.,  4.,  7., 16.,  7.,  0.],
#        [ 0.,  0.,  0.,  0.,  4., 16.,  9.,  0.],
#        [ 0.,  0.,  5.,  4., 12., 16.,  4.,  0.],
#        [ 0.,  0.,  9., 16., 16., 10.,  0.,  0.]])

# %% [markdown]
# segregate dataset into x and y

# %%
X = dataset.images.reshape((dataimageLength,-1))
X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
Y = dataset.target
Y
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %% [markdown]
# split to train and test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1347, 64)
# (450, 64)

# %% [markdown]
# training

# %%
from sklearn import svm
model = svm.SVC(kernel="linear")
model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# prediction

# %%
n=27
result = model.predict(dataset.images[n].reshape((1,-1)))
plt.imshow(dataset.images[n], cmap=plt.cm.gray_r, interpolation='nearest')     
print(result)
print("\n")
#plt.axis('off')
plt.title('%i' %result)
plt.show()
# Out:
# [7]

# %% [markdown]
# Prediction for test data

# %%
y_pred = model.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), Y_test.reshape(len(Y_test),1)),1))
# Out:
# [[2 2]
#  [8 8]
#  [2 2]
#  [6 6]
#  [6 6]
#  [7 7]
#  [1 1]
#  [9 9]
#  [8 8]
#  [5 5]
#  [2 2]
#  [8 8]
#  [6 6]
#  [6 6]
#  [6 6]
#  [6 6]
#  [1 1]
#  [0 0]
#  [5 5]
#  [8 8]
#  [8 8]
#  [7 7]
#  [8 8]
#  [4 4]
#  [7 7]
#  [5 5]
#  [4 4]
#  [9 9]
#  [2 2]
#  [9 9]
#  [4 4]
#  [7 7]
#  [6 6]
#  [8 8]
#  [9 9]
#  [4 4]
#  [3 3]
#  [1 1]
#  [0 0]
#  [1 1]
#  [8 8]
#  [6 6]
#  [7 7]
#  [7 7]
#  [1 1]
#  [0 0]
#  [7 7]
#  [6 6]
#  [2 2]
#  [1 1]
#  [9 9]
#  [6 6]
#  [7 7]
#  [9 9]
#  [0 0]
#  [0 0]
#  [5 5]
#  [1 1]
#  [6 6]
#  [3 3]
#  [0 0]
#  [2 2]
#  [3 3]
#  [4 4]
#  [1 1]
#  [9 9]
#  [2 2]
#  [6 6]
#  [9 9]
#  [1 1]
#  [8 8]
#  [3 3]
#  [5 5]
#  [1 1]
#  [2 2]
#  [8 8]
#  [2 2]
#  [2 2]
#  [9 9]
#  [7 7]
#  [2 2]
#  [3 3]
#  [6 6]
#  [0 0]
#  [5 5]
#  [3 3]
#  [7 7]
#  [5 5]
#  [1 1]
#  [2 2]
#  [9 9]
#  [9 9]
#  [3 3]
#  [1 1]
#  [7 7]
#  [7 7]
#  [4 4]
#  [8 8]
#  [5 5]
#  [8 8]
#  [5 5]
#  [5 5]
#  [2 2]
#  [5 5]
#  [9 9]
#  [0 0]
#  [7 7]
#  [1 1]
#  [4 4]
#  [4 7]
#  [3 3]
# ...

# %% [markdown]
# evaluate model

# %%
from sklearn.metrics import accuracy_score
print("Accuracy of the Model: {0}%".format(accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy of the Model: 97.11111111111111%

# %% [markdown]
# Play with different mothods

# %%
from sklearn import svm
model1 = svm.SVC(kernel='linear')
model2 = svm.SVC(kernel='rbf')
model3 = svm.SVC(gamma=0.001)
model4 = svm.SVC(gamma=0.001,C=1.0)

model1.fit(X_train,Y_train)
model2.fit(X_train,Y_train)
model3.fit(X_train,Y_train)
model4.fit(X_train,Y_train)

Y_predictmodel1 = model1.predict(X_test)
Y_predictmodel2 = model2.predict(X_test)
Y_predictmodel3 = model3.predict(X_test)
Y_predictmodel4 = model4.predict(X_test)

print("Accuracy of the Model 1: {0}%".format(accuracy_score(Y_test, Y_predictmodel1)*100))
print("Accuracy of the Model 2: {0}%".format(accuracy_score(Y_test, Y_predictmodel2)*100))
print("Accuracy of the Model 3: {0}%".format(accuracy_score(Y_test, Y_predictmodel3)*100))
print("Accuracy of the Model 4: {0}%".format(accuracy_score(Y_test, Y_predictmodel4)*100))
# Out:
# Accuracy of the Model 1: 97.11111111111111%
# Accuracy of the Model 2: 99.11111111111111%
# Accuracy of the Model 3: 99.55555555555556%
# Accuracy of the Model 4: 99.55555555555556%
